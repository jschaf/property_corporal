# %%
from property_corporal import consolidated_propery_list as cpl

# %%
# !pwd
# Out:
# /c/Users/joe/prog/property_corporal

# %%
d = cpl.parse_file("property_corporal/tests/cpl-short.xlsx")

# %%
d
# Out:
# [{'aac': None,
#   'appropriation_budget_activity': '2',
#   'authorized': 1,
#   'controlled_item_inventory_code': 'U',
#   'detect_serial_number': None,
#   'document_number': None,
#   'due-in': 0,
#   'ecc': 'SV',
#   'ecs': None,
#   'erc': None,
#   'estimated_ship_date': None,
#   'line_item_number': '70029N',
#   'log': None,
#   'logistics_control_code': 'R',
#   'mtoe_required': 0,
#   'nsn': '673001C059298',
#   'nsn nomenclature': 'PROJECTOR OVERHEAD, W/WO ACCESS TY : SX1',
#   'on-hand': 1,
#   'pbic': '0',
#   'record_type': None,
#   'registration_number': None,
#   'reportable_item_control_code': '0',
#   'serial_number': '712913772',
#   'sub_line_item_number': None,
#   'supply_code': None,
#   'system_number': None,
#   'tac': '3',
#   'unit_id_code': 'WG6CE0',
#   'unit_issue': 'EA',
#   'unit_price': Decimal('11799.00')},
#  {'aac': None,
#   'appropriation_budget_activity': '2',
#   'authorized': 1,
#   'controlled_item_inventory_code': 'U',
# ...

# %%
from decimal import Decimal

# %%
a = Decimal("399.99")

# %%
a.quantize?

# %%
a
# Out:
# Decimal('399.99')

# %%
    def cast_to_decimal(amount):
        TWOPLACES = Decimal(10) ** -2
        if amount == '':
            return None
        else:
            return Decimal(amount).quantize(TWOPLACES)

# %%
cast_to_decimal("0.019")
# Out:
# Decimal('0.02')
